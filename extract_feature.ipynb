# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json
import pandas as pd

# %%
client_id = "5356afb958c84e71a2c37c43e2a2cbf2" 
client_secret = "83e531491e9c458ba658ac30c4c56bc0"

#use the clint secret and id details
client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
URL="https://open.spotify.com/playlist/37i9dQZF1EVKuMoAJjoTIw?si=bc27e71c049e4905"

# %%
playlist_id = URL.split("/")[4].split("?")[0]
playlist_tracks_data = sp.playlist_tracks(playlist_id)

# %%
playlist_id
# Out:
# '37i9dQZF1EVKuMoAJjoTIw'

# %%
playlist_tracks_id = []

# %%
for track in playlist_tracks_data['items']:
    playlist_tracks_id.append(track['track']['id'])

# %%
playlist_tracks_id
# Out:
# ['1ei3hzQmrgealgRKFxIcWn',
#  '3UmaczJpikHgJFyBTAJVoz',
#  '1ugQtcwmKOXvKAYzhjncmv',
#  '60iSKGrGazRzICtMjADNSM',
#  '4ZLzoOkj0MPWrTLvooIuaa',
#  '7m9OqQk4RVRkw9JJdeAw96',
#  '4CxFN5zON70B3VOPBYbd6P',
#  '6J2LdBN97cDWn0MLxYh9HB',
#  '44n97yHySt0Z9rqPaXgjCK',
#  '3i5qVV8azKqGFK4Gzdt5YS',
#  '4UKCKdYiLN6IMA5ZESUTL7',
#  '5qrSlOut2rNAWv3ubArkNy',
#  '4VuS959DSpr82t3qBqCrWG',
#  '1TQXIltqoZ5XXyfCbAeSQQ',
#  '0j1Ia2lQWrcXrQZI4AdJlk',
#  '6xGruZOHLs39ZbVccQTuPZ',
#  '5uCax9HTNlzGybIStD3vDh',
#  '5vjLSffimiIP26QG5WcN2K',
#  '2RttW7RAu5nOAfq6YFvApB',
#  '4Yxc55NX3tAXC2mHRAhtcW',
#  '2qxmye6gAegTMjLKEBoR3d',
#  '6ATgDc6e4sPn84hvJsAmPt',
#  '0ecC8p17cDNlxHXkuYqeR6',
#  '4KlL5Bwlm4yHYxr0B2rHci',
#  '6CcJMwBtXByIz4zQLzFkKc',
#  '5DqdesEfbRyOlSS3Tf6c29',
#  '5de9Ho64dovuQI8Uhn5gPD',
#  '3S8jK1mGzQi24ilFb45DAZ',
#  '2AHKsVXN6BjBO8SEVX6cBC',
#  '1kFlDnWmBTvCBxxeGDpIdp',
#  '50OPOdJbRx9iCJXGultmUf',
#  '1almCHdsfikRPfVB9VrEdT',
#  '2ZRo7axmMPeSVUvDbGkJah',
#  '7qEHsqek33rTcFNT9PFqLf',
# ...

# %%
features = sp.audio_features(playlist_tracks_id)

# %%
features[0]
# Out:
# {'danceability': 0.362,
#  'energy': 0.54,
#  'key': 10,
#  'loudness': -6.031,
#  'mode': 1,
#  'speechiness': 0.0528,
#  'acousticness': 0.338,
#  'instrumentalness': 0,
#  'liveness': 0.139,
#  'valence': 0.3,
#  'tempo': 78.007,
#  'type': 'audio_features',
#  'id': '1ei3hzQmrgealgRKFxIcWn',
#  'uri': 'spotify:track:1ei3hzQmrgealgRKFxIcWn',
#  'track_href': 'https://api.spotify.com/v1/tracks/1ei3hzQmrgealgRKFxIcWn',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1ei3hzQmrgealgRKFxIcWn',
#  'duration_ms': 216410,
#  'time_signature': 3}

# %%
features_df = pd.DataFrame(data=features, columns=features[0].keys())
features_df=features_df[['danceability','energy','loudness','speechiness','acousticness','instrumentalness','liveness','valence','tempo','key','duration_ms','id']]

# %%
features_df
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.362  0.5400    -6.031       0.0528        0.3380
# 1          0.780  0.7680    -4.325       0.2380        0.0371
# 2          0.507  0.2040   -11.575       0.0504        0.8550
# 3          0.688  0.5300    -5.507       0.0333        0.4430
# 4          0.498  0.2350   -16.541       0.1880        0.7200
# 5          0.872  0.3910    -9.144       0.2420        0.4690
# 6          0.561  0.0848   -15.099       0.0404        0.9130
# 7          0.708  0.1860    -8.953       0.0420        0.8680
# 8          0.513  0.2500    -9.376       0.0367        0.9130
# 9          0.551  0.3860   -10.220       0.1320        0.6590
# 10         0.699  0.3040   -11.192       0.0993        0.7790
# 11         0.551  0.5370    -7.595       0.0340        0.7050
# 12         0.589  0.2420   -10.517       0.0442        0.9140
# 13         0.629  0.3280    -8.284       0.0290        0.7680
# ...
